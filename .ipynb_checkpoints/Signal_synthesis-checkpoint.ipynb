# %%
import torchaudio as ta
import matplotlib.pyplot as plt
import torch
import pytorch_lightning as pl

import os

import librosa

import IPython.display as ipd

import numpy as np

import pandas as pd

import glob

from tqdm.auto import tqdm

from numba import jit

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
device
# Out:
# device(type='cuda')

# %%
noise_dir = "./dataset/UrbanSound8K/audio/"
noise_metadata = "./dataset/UrbanSound8K/metadata/UrbanSound8K.csv"

signal_dir = "./dataset/cv-corpus-5.1-2020-06-22/en/clips/"
signal_metadata = "./dataset/cv-corpus-5.1-2020-06-22/en/train.tsv"

noise_df = pd.read_csv(noise_metadata)
signal_df = pd.read_csv(signal_metadata, sep="\t")

# %%
signal_df.head()
# Out:
#                                            client_id  \
# 0  f1f6414c04e74453065e1b7fc1639c6f728dc03ed95890...
# 1  f1f6414c04e74453065e1b7fc1639c6f728dc03ed95890...
# 2  f1f6414c04e74453065e1b7fc1639c6f728dc03ed95890...
# 3  f1f6414c04e74453065e1b7fc1639c6f728dc03ed95890...
# 4  f208e11e4b036d4728602fef34b9f1158faa601f20c63a...
#
#                            path  \
# 0  common_voice_en_20009651.mp3
# 1  common_voice_en_20009653.mp3
# 2  common_voice_en_20009655.mp3
# 3  common_voice_en_20009654.mp3
# 4  common_voice_en_19684651.mp3
#
#                                             sentence  up_votes  down_votes  \
# 0                          It just didn't seem fair.         2           1
# 1  The anticipated synergies of the two modes of ...         2           0
# 2  The fossil fuels include coal, petroleum and n...         3           1
# 3      Eventually, they named the complex after him.         2           0
# 4  He was the grandfather of Arent S. Crowninshield.         2           0
#
#    age gender accent locale  segment
# 0  NaN    NaN    NaN     en      NaN
# 1  NaN    NaN    NaN     en      NaN
# 2  NaN    NaN    NaN     en      NaN
# 3  NaN    NaN    NaN     en      NaN
# 4  NaN    NaN    NaN     en      NaN

# %%
noise_paths = []
for root, dirs, files in os.walk(noise_dir):
    for name in files:
        if name.endswith(".wav"):
            noise_paths.append(os.path.join(root, name))
        

# @jit(nopython=True)
def get_sinal_paths(signal_dir):
    
    signal_paths = []
    for file in tqdm(os.listdir(signal_dir)):
        if file.endswith(".mp3"):
            signal_paths.append(os.path.join(signal_dir, file))
    return signal_paths

signal_paths = get_sinal_paths(signal_dir)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1427394.0), HTML(value='')))

# %%
len(signal_paths), signal_paths[0]
# Out:
# (1427394,
#  './dataset/cv-corpus-5.1-2020-06-22/en/clips/common_voice_en_20367387.mp3')

# %%
len(noise_paths)
# Out:
# 8732

# %%
def get_noise_from_sound(signal, noise, SNR):
    RMS_s = torch.sqrt(torch.mean(signal**2))
    
    RMS_n = torch.sqrt(RMS_s**2/pow(10., SNR/10))
    
    RMS_n_current = torch.sqrt(torch.mean(noise**2))
    noise = noise*(RMS_n/RMS_n_current)

    return noise

def get_mixed_signal(signal: torch.Tensor, noise: torch.Tensor, ssr: int, nsr: int, SNR):
    
    noise_len = len(noise)
    signal_len = len(noise)
    
    if len(noise) > len(signal):
        noise = noise[0 : len(signal)]
    elif len(noise) < len(signal):
        
        #noise = torch.cat((noise, torch.zeros((len(signal) - len(noise)))))
        for i in range(int(len(signal)/len(noise))+1):
            noise = torch.cat((noise, noise))
            
        noise = noise[:len(signal)]
        
    noise = get_noise_from_sound(signal, noise, SNR)
    
    signal_noise = signal+noise
    return signal_noise

# %%
SNR = np.random.randint(0, 50)
# noise, nsr = librosa.load(noise_paths[100])
# signal, ssr = librosa.load("./dataset/cv-corpus-5.1-2020-06-22/en/clips/common_voice_en_20000067.mp3")
noise, nsr = ta.load(noise_paths[100], normalization=True)
signal, ssr = ta.load(signal_paths[100])

noise = noise.view(noise.size)
signal = signal.numpy()

# %%
noise
# Out:
# tensor([[ 0.0555,  0.0574,  0.0660,  ...,  0.0039,  0.0141, -0.0034],
#         [ 0.0294,  0.0251,  0.0112,  ..., -0.0019,  0.0115,  0.0132]])

# %%
SNR
# Out:
# 39

# %%
pre_emphasis = 0.95
# noise = np.interp(noise, (noise.min(), noise.max()), (-1, 1))
# signal = np.interp(signal, (signal.min(), noise.max()), (-1, 1))

noise = torch.cat((noise[0], noise[1:] - pre_emphasis * noise[:-1]))
signal = torch.cat((signal[0], signal[1:] - pre_emphasis * signal[:-1]))

# noise = torch.tensor(torch.from_numpy(noise), dtype=torch.double)
# signal = torch.from_numpy(signal).double()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-65-c11cf7fe2bc4> in <module>
#       3 # signal = np.interp(signal, (signal.min(), noise.max()), (-1, 1))
#       4
# ----> 5 noise = torch.cat((noise[0], noise[1:] - pre_emphasis * noise[:-1]))
#       6 signal = torch.cat((signal[0], signal[1:] - pre_emphasis * signal[:-1]))
#       7
#
# RuntimeError: Tensors must have same number of dimensions: got 1 and 2

# %%
noise
# Out:
# tensor([-0.0031, -0.0400, -0.0161,  ..., -0.0078, -0.0287,  0.0239],
#        dtype=torch.float64)

# %%
# SNR = 0
signal_noise = get_mixed_signal(signal, noise, ssr, nsr, SNR)

# %%
#noise = torch.from_numpy(noise)

fig, axes = plt.subplots(2, 1)

axes[0].plot(noise.t().numpy())

specgram = ta.transforms.MelSpectrogram()(noise)
axes[1].imshow(specgram.log2()[:, :].numpy(), cmap="inferno")

noise.mean()
specgram.log2()[:, :].numpy().shape
sr = ssr
x = noise.numpy()
ipd.Audio(x, rate=ssr)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-39-fdea31367b04> in <module>
#       5 axes[0].plot(noise.t().numpy())
#       6
# ----> 7 specgram = ta.transforms.MelSpectrogram()(noise)
#       8 axes[1].imshow(specgram.log2()[:, :].numpy(), cmap="inferno")
#       9
#
# /mnt/sda4/vamsik1211/Data/ML/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# /mnt/sda4/vamsik1211/Data/ML/lib/python3.7/site-packages/torchaudio/transforms.py in forward(self, waveform)
#     425         """
#     426         specgram = self.spectrogram(waveform)
# --> 427         mel_specgram = self.mel_scale(specgram)
#     428         return mel_specgram
#     429
#
# /mnt/sda4/vamsik1211/Data/ML/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# /mnt/sda4/vamsik1211/Data/ML/lib/python3.7/site-packages/torchaudio/transforms.py in forward(self, specgram)
#     258         # (channel, frequency, time).transpose(...) dot (frequency, n_mels)
#     259         # -> (channel, time, n_mels).transpose(...)
# --> 260         mel_specgram = torch.matmul(specgram.transpose(1, 2), self.fb).transpose(1, 2)
#     261
#     262         # unpack batch
#
# RuntimeError: Expected object of scalar type Double but got scalar type Float for argument #3 'mat2' in call to _th_addmm_out

# %%
fig, axes = plt.subplots(2, 1)

axes[0].plot(signal.t().numpy())

specgram = ta.transforms.Spectrogram()(signal)
axes[1].imshow(specgram.log2().numpy(), cmap="inferno")
sr = ssr
x = signal.numpy()
ipd.Audio(x, rate=ssr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fig, axes = plt.subplots(2, 1)

axes[0].plot(signal_noise.t().numpy())

specgram = ta.transforms.Spectrogram()(signal_noise)
axes[1].imshow(specgram.log2().numpy(), cmap="inferno")
sr = ssr
x = signal_noise.numpy()
ipd.Audio(x, rate=ssr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
noise_dir = "./dataset/UrbanSound8K/audio/"
noise_metadata = "./dataset/UrbanSound8K/metadata/UrbanSound8K.csv"

signal_dir = "./dataset/cv-corpus-5.1-2020-06-22/en/clips/"
signal_metadata = "./dataset/cv-corpus-5.1-2020-06-22/en/train.tsv"

# %%
noise_df = pd.read_csv(noise_metadata)
signal_df = pd.read_csv(signal_metadata, sep="\t")

# %%
signal_path = os.path.join(signal_dir, signal_df["path"][1])

# %%
signal_path
# Out:
# './dataset/cv-corpus-5.1-2020-06-22/en/clips/common_voice_en_20009653.mp3'

# %%
noise_df.head(5)
# Out:
#       slice_file_name    fsID  start        end  salience  fold  classID  \
# 0    100032-3-0-0.wav  100032    0.0   0.317551         1     5        3
# 1  100263-2-0-117.wav  100263   58.5  62.500000         1     5        2
# 2  100263-2-0-121.wav  100263   60.5  64.500000         1     5        2
# 3  100263-2-0-126.wav  100263   63.0  67.000000         1     5        2
# 4  100263-2-0-137.wav  100263   68.5  72.500000         1     5        2
#
#               class
# 0          dog_bark
# 1  children_playing
# 2  children_playing
# 3  children_playing
# 4  children_playing
